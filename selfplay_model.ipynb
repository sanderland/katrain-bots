# %%
import json
import math
import pickle
import sys
import threading
import time
import traceback
from collections import defaultdict
from concurrent.futures.thread import ThreadPoolExecutor
import numpy as np
from elote import EloCompetitor
from katrain.core.constants import (
    AI_LOCAL,
    AI_RANK,
    AI_TENUKI,
    AI_WEIGHTED,
    AI_PICK,
    AI_TERRITORY,
    AI_POLICY,
)

from settings import Logger
import matplotlib.pyplot as plt
# Out:
# [INFO   ] [Logger      ] Record log in /home/sander/.kivy/logs/kivy_20-07-02_2.txt
# [INFO   ] [Kivy        ] v2.0.0rc2, git-Unknown, 20200701
# [INFO   ] [Kivy        ] Installed at "/home/sander/anaconda3/lib/python3.7/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# [INFO   ] [Python      ] Interpreter at "/home/sander/anaconda3/bin/python"

# %%
DB_FILENAME = "tournament_ai_performance.pickle"
class AI:
    def fix_settings(self):
        pass

try:
    with open(DB_FILENAME, "rb") as f:
        ai_database_loaded, all_results = pickle.load(f)
        ai_database = []
        for ai in ai_database_loaded:
            try:
                ai.fix_settings()  # update as required
                ai_database.append(ai)
            except Exception as e:
                print("Error loading AI", ai.strategy,e)
except FileNotFoundError:
    ai_database = []
    all_results = []

# %%
from sklearn.linear_model import LinearRegression
ranked = [ai for ai in ai_database if ai.strategy==AI_RANK]
calibrate = [ai for ai in ai_database if ai.strategy==AI_WEIGHTED]
policy = [ai for ai in ai_database if ai.strategy==AI_POLICY and ai.ai_settings['opening_moves']==0][0]

kyu_elo = [(r.ai_settings['kyu_rank'],r.elo_comp.rating) for r in ranked]
#kyu_elo.append( (-5,policy.elo_comp.rating) ) # policy ~5d
kyu_elo = sorted(kyu_elo)
kyu,elo = zip(*kyu_elo)

wt_elo =  [([r.ai_settings['weaken_fac'],-math.log(r.ai_settings['lower_bound']),1-r.ai_settings.get('pick_override',1)],r.elo_comp.rating) for r in calibrate]

x,y = zip(*wt_elo)
reg = LinearRegression().fit(x, y)

# %%
kyu2 = np.array(kyu)[:,np.newaxis]
reg = LinearRegression().fit(kyu2,elo)
plt.plot(kyu,elo,kyu,reg.predict(kyu2))
# Out:
# [<matplotlib.lines.Line2D at 0x7fe680aeb1d0>,
#  <matplotlib.lines.Line2D at 0x7fe680aeb2e8>]

# %%
list(zip(kyu,reg.predict(kyu2)))
# Out:
# [(-4, 1112.802892326076),
#  (-3, 1069.9095810474219),
#  (-2, 1027.0162697687679),
#  (-1, 984.1229584901139),
#  (0, 941.2296472114598),
#  (1, 898.3363359328057),
#  (2, 855.4430246541517),
#  (3, 812.5497133754976),
#  (4, 769.6564020968435),
#  (5, 726.7630908181895),
#  (6, 683.8697795395354),
#  (7, 640.9764682608813),
#  (8, 598.0831569822274),
#  (9, 555.1898457035733),
#  (10, 512.2965344249192),
#  (11, 469.40322314626513),
#  (12, 426.5099118676111),
#  (13, 383.616600588957),
#  (14, 340.7232893103029),
#  (15, 297.8299780316489),
#  (16, 254.93666675299482),
#  (17, 212.04335547434073),
#  (18, 169.15004419568675)]

# %%
reg.predict(x)
# Out:
# array([1402.52138477, 1131.0916944 ,  995.37684921,  859.66200402,
#         723.94715884,  588.23231365,  452.51746846])

# %%
y
# Out:
# (1424.4687011700541,
#  1144.2851969464448,
#  983.473460365626,
#  849.2779807201654,
#  683.2503739146116,
#  528.7927812269777,
#  539.8003790064159)

# %%
for ai in sorted(ai_database,key=lambda a:-a.elo_comp.rating):
    print(ai.elo_comp.rating,'\t',ai.name)
# Out:
# 1862.4755993496708 	 ai:p:local(pick_frac=0.75,pick_n=50)
# 1810.7581765529053 	 ai:policy(opening_moves=0)
# 1808.1013445280687 	 ai:p:tenuki(pick_frac=1.0,pick_n=5)
# 1806.016528465102 	 ai:p:local(pick_frac=1.0,pick_n=50)
# 1776.9993959697324 	 ai:p:tenuki(pick_frac=1.0,pick_n=50)
# 1774.6576877746747 	 ai:p:territory(pick_frac=1.0,pick_n=5)
# 1771.7457599478712 	 ai:p:territory(pick_frac=1.0,pick_n=0)
# 1754.5176666496104 	 ai:p:local(pick_frac=1.0,pick_n=0)
# 1753.1288791509307 	 ai:p:tenuki(pick_frac=1.0,pick_n=25)
# 1742.8293951807038 	 ai:p:local(pick_frac=1.0,pick_n=5)
# 1735.035287819561 	 ai:p:territory(pick_frac=1.0,pick_n=50)
# 1724.2686693543678 	 ai:p:tenuki(pick_frac=1.0,pick_n=0)
# 1723.7260106746908 	 ai:p:territory(pick_frac=1.0,pick_n=10)
# 1718.5697631470948 	 ai:p:tenuki(pick_frac=1.0,pick_n=15)
# 1715.1999921287709 	 ai:p:local(pick_frac=1.0,pick_n=10)
# 1702.1601442041158 	 ai:p:local(pick_frac=1.0,pick_n=25)
# 1685.7506704792147 	 ai:p:local(pick_frac=0.75,pick_n=5)
# 1683.426243648616 	 ai:p:territory(pick_frac=1.0,pick_n=25)
# 1681.0880735517599 	 ai:policy()
# 1679.4450369089543 	 ai:p:local(pick_frac=0.75,pick_n=25)
# 1678.9341660402988 	 ai:p:local(pick_frac=1.0,pick_n=15)
# 1671.946141187762 	 ai:p:territory(pick_frac=1.0,pick_n=15)
# 1667.4958957102363 	 ai:p:tenuki(pick_frac=1.0,pick_n=10)
# 1644.784715816971 	 ai:p:pick(pick_frac=0.0,pick_n=0)
# 1633.9295788764136 	 ai:p:pick(pick_frac=1.0,pick_n=15)
# 1633.7020637052474 	 ai:p:local(pick_frac=0.75,pick_n=0)
# 1629.660715346734 	 ai:p:pick(pick_frac=0.75,pick_n=50)
# 1629.0225579430542 	 ai:p:pick(pick_frac=1.0,pick_n=5)
# 1627.5859326878801 	 ai:p:local(pick_frac=0.75,pick_n=10)
# 1627.339149566869 	 ai:p:pick(pick_frac=1.0,pick_n=25)
# 1620.1747967771475 	 ai:p:territory(pick_frac=0.75,pick_n=50)
# 1616.8293820562383 	 ai:p:local(pick_frac=0.75,pick_n=15)
# 1614.8244619921838 	 ai:p:pick(pick_frac=1.0,pick_n=50)
# 1607.4490295462513 	 ai:p:pick(pick_frac=1.0,pick_n=10)
# 1596.478120118057 	 ai:p:local(pick_frac=0.5,pick_n=50)
# 1587.748816708962 	 ai:p:pick(pick_frac=1.0,pick_n=0)
# 1535.2212804680414 	 ai:p:pick(pick_frac=0.75,pick_n=25)
# 1533.5903932230808 	 ai:p:local(pick_frac=0.3,pick_n=50)
# 1519.9876845373592 	 ai:p:influence(pick_frac=0.75,pick_n=5)
# 1515.3017015073788 	 ai:p:local(pick_frac=0.5,pick_n=25)
# 1510.1927015853596 	 ai:p:influence(pick_frac=1.0,pick_n=50)
# 1508.900745184156 	 ai:p:pick(pick_frac=0.75,pick_n=15)
# 1488.744855509504 	 ai:p:territory(pick_frac=0.75,pick_n=25)
# 1470.994199144585 	 ai:p:tenuki(pick_frac=0.0,pick_n=0)
# 1465.462954551226 	 ai:p:influence(pick_frac=1.0,pick_n=0)
# 1460.7524267816154 	 ai:p:pick(pick_frac=0.75,pick_n=0)
# 1457.275862841276 	 ai:p:local(pick_frac=0.5,pick_n=5)
# 1446.4141018778078 	 ai:p:influence(pick_frac=1.0,pick_n=5)
# 1437.3590702899003 	 ai:p:influence(pick_frac=0.75,pick_n=15)
# 1433.2928968465137 	 ai:p:local(pick_frac=0.5,pick_n=10)
# 1431.68469817797 	 ai:p:influence(pick_frac=0.75,pick_n=50)
# 1429.9408500861275 	 ai:p:influence(pick_frac=1.0,pick_n=15)
# 1429.1847573730465 	 ai:p:local(pick_frac=0.0,pick_n=0)
# 1427.3961721484106 	 ai:p:pick(pick_frac=0.75,pick_n=10)
# 1424.4687011700541 	 ai:p:weighted(weaken_fac=0.5)
# 1415.7166513946693 	 ai:p:local(pick_frac=0.5,pick_n=15)
# 1411.200880594923 	 ai:p:territory(pick_frac=0.75,pick_n=15)
# 1397.737502062249 	 ai:p:pick(pick_frac=0.5,pick_n=50)
# 1388.4365116108315 	 ai:p:territory(pick_frac=0.5,pick_n=50)
# 1385.9048271162785 	 ai:p:tenuki(pick_frac=0.75,pick_n=50)
# 1380.4789008982468 	 ai:p:territory(pick_frac=0.75,pick_n=0)
# 1380.2481730364218 	 ai:p:territory(pick_frac=0.75,pick_n=10)
# 1378.0169139562527 	 ai:p:influence(pick_frac=0.75,pick_n=25)
# 1373.783490023324 	 ai:p:local(pick_frac=0.3,pick_n=10)
# 1367.6385690104528 	 ai:p:influence(pick_frac=0.75,pick_n=0)
# 1364.7434601747805 	 ai:p:influence(pick_frac=0.75,pick_n=10)
# 1362.6932905116926 	 ai:p:local(pick_frac=0.5,pick_n=0)
# 1362.6077655069876 	 ai:p:territory(pick_frac=0.75,pick_n=5)
# 1359.2226948268835 	 ai:p:influence(pick_frac=0.5,pick_n=50)
# 1350.5209440952854 	 ai:p:influence(pick_frac=1.0,pick_n=25)
# 1346.1084663426225 	 ai:p:influence(pick_frac=1.0,pick_n=10)
# 1334.1591183237933 	 ai:p:pick(pick_frac=0.75,pick_n=5)
# 1313.7199138008907 	 ai:p:local(pick_frac=0.3,pick_n=25)
# 1305.0608050927606 	 ai:p:territory(pick_frac=0.5,pick_n=25)
# 1303.816444337302 	 ai:p:local(pick_frac=0.1,pick_n=50)
# 1298.812405967819 	 ai:p:local(pick_frac=0.2,pick_n=15)
# 1297.1180981742777 	 ai:p:local(pick_frac=0.3,pick_n=0)
# 1293.072351118086 	 ai:p:influence(pick_frac=0.0,pick_n=0)
# 1276.9193376260257 	 ai:p:tenuki(pick_frac=0.75,pick_n=25)
# 1275.3346316453776 	 ai:p:territory(pick_frac=0.0,pick_n=0)
# 1260.316741031992 	 ai:p:local(pick_frac=0.3,pick_n=15)
# 1258.8283867061425 	 ai:p:local(pick_frac=0.2,pick_n=25)
# 1257.2264480285203 	 ai:p:local(pick_frac=0.2,pick_n=10)
# 1251.9981360572021 	 ai:p:tenuki(pick_frac=0.75,pick_n=10)
# 1250.708394540777 	 ai:p:pick(pick_frac=0.5,pick_n=15)
# 1249.119082985298 	 ai:p:tenuki(pick_frac=0.75,pick_n=5)
# 1246.2188815131435 	 ai:p:local(pick_frac=0.2,pick_n=50)
# 1244.3379627432928 	 ai:p:local(pick_frac=0.1,pick_n=25)
# 1233.9711613139748 	 ai:p:tenuki(pick_frac=0.75,pick_n=15)
# 1233.0960067251945 	 ai:p:pick(pick_frac=0.5,pick_n=25)
# 1230.3366862933156 	 ai:p:local(pick_frac=0.1,pick_n=10)
# 1222.0924548108114 	 ai:p:local(pick_frac=0.2,pick_n=5)
# 1220.303233621439 	 ai:p:tenuki(pick_frac=0.75,pick_n=0)
# 1217.2603091400872 	 ai:p:local(pick_frac=0.0,pick_n=50)
# 1210.6566147952476 	 ai:p:pick(pick_frac=0.3,pick_n=50)
# 1208.76497616101 	 ai:p:tenuki(pick_frac=0.5,pick_n=25)
# 1207.8777170238495 	 ai:p:local(pick_frac=0.05,pick_n=50)
# 1207.1367169754897 	 ai:p:local(pick_frac=0.3,pick_n=5)
# 1205.1581084239099 	 ai:p:local(pick_frac=0.1,pick_n=5)
# 1205.0606782232373 	 ai:p:influence(pick_frac=0.5,pick_n=10)
# 1203.5399227838955 	 ai:p:influence(pick_frac=0.5,pick_n=25)
# 1201.502149490139 	 ai:p:tenuki(pick_frac=0.5,pick_n=50)
# 1200.1839437151218 	 ai:p:local(pick_frac=0.0,pick_n=25)
# 1177.1281140860174 	 ai:p:local(pick_frac=0.1,pick_n=15)
# 1155.9332517137548 	 ai:p:influence(pick_frac=0.5,pick_n=15)
# 1152.6429223541681 	 ai:p:territory(pick_frac=0.3,pick_n=50)
# 1148.2123760193124 	 ai:p:pick(pick_frac=0.5,pick_n=5)
# 1144.2851969464448 	 ai:p:weighted(weaken_fac=1.0)
# 1132.9496659114398 	 ai:p:influence(pick_frac=0.5,pick_n=0)
# 1125.949545474256 	 ai:p:tenuki(pick_frac=0.5,pick_n=15)
# 1114.742870950803 	 ai:p:local(pick_frac=0.05,pick_n=15)
# 1109.303712487787 	 ai:p:local(pick_frac=0.2,pick_n=0)
# 1091.4875016162837 	 ai:p:rank(kyu_rank=-1)
# 1089.2297790208072 	 ai:p:territory(pick_frac=0.5,pick_n=5)
# 1088.1550436543143 	 ai:p:local(pick_frac=0.05,pick_n=25)
# 1085.9728880199118 	 ai:p:territory(pick_frac=0.5,pick_n=15)
# 1083.3195963060114 	 ai:p:local(pick_frac=0.1,pick_n=0)
# 1083.2938227404734 	 ai:p:pick(pick_frac=0.5,pick_n=10)
# 1081.4558568000248 	 ai:p:influence(pick_frac=0.3,pick_n=25)
# 1073.9651148046232 	 ai:p:territory(pick_frac=0.5,pick_n=10)
# 1067.553512616882 	 ai:p:influence(pick_frac=0.5,pick_n=5)
# 1064.3561502151379 	 ai:p:rank(kyu_rank=-3)
# 1060.4855031833542 	 ai:p:local(pick_frac=0.05,pick_n=10)
# 1059.3324927495983 	 ai:p:influence(pick_frac=0.3,pick_n=50)
# 1058.4140208494034 	 ai:p:pick(pick_frac=0.5,pick_n=0)
# 1052.4529347427617 	 ai:p:territory(pick_frac=0.5,pick_n=0)
# 1050.7144844759887 	 ai:p:influence(pick_frac=0.2,pick_n=50)
# 1045.6245241931622 	 ai:p:tenuki(pick_frac=0.3,pick_n=50)
# 1043.6733469876947 	 ai:p:influence(pick_frac=0.3,pick_n=5)
# 1032.1559821634442 	 ai:p:tenuki(pick_frac=0.5,pick_n=10)
# 1026.5533254574007 	 ai:p:rank(kyu_rank=-4)
# 1019.9517236043761 	 ai:p:local(pick_frac=0.05,pick_n=5)
# 1017.8443064898793 	 ai:p:territory(pick_frac=0.2,pick_n=50)
# 1013.0504999054743 	 ai:p:influence(pick_frac=0.3,pick_n=15)
# 1011.0987592588384 	 ai:p:tenuki(pick_frac=0.5,pick_n=5)
# 1003.7523398599355 	 ai:p:influence(pick_frac=0.1,pick_n=50)
# 1003.5225833341707 	 ai:p:territory(pick_frac=0.3,pick_n=25)
# 1000.7987372027724 	 ai:p:tenuki(pick_frac=0.5,pick_n=0)
# 998.2977195890895 	 ai:p:rank(kyu_rank=-2)
# 994.1421287816919 	 ai:p:local(pick_frac=0.0,pick_n=15)
# 992.4005348599438 	 ai:p:rank(kyu_rank=0)
# 983.473460365626 	 ai:p:weighted(weaken_fac=1.25)
# 982.4860662149994 	 ai:p:territory(pick_frac=0.3,pick_n=0)
# 982.2981164741622 	 ai:p:pick(pick_frac=0.2,pick_n=50)
# 965.572253998364 	 ai:p:territory(pick_frac=0.3,pick_n=10)
# 963.8656033769173 	 ai:p:influence(pick_frac=0.2,pick_n=25)
# 958.8382139838469 	 ai:p:pick(pick_frac=0.3,pick_n=25)
# 950.9942648874458 	 ai:p:territory(pick_frac=0.3,pick_n=15)
# 938.3760527073342 	 ai:p:territory(pick_frac=0.3,pick_n=5)
# 931.6093815586895 	 ai:p:tenuki(pick_frac=0.2,pick_n=50)
# 931.0840102736685 	 ai:p:territory(pick_frac=0.2,pick_n=25)
# 921.7407242549215 	 ai:p:tenuki(pick_frac=0.2,pick_n=25)
# 921.7003363581416 	 ai:p:tenuki(pick_frac=0.3,pick_n=15)
# 921.1262727134492 	 ai:p:territory(pick_frac=0.2,pick_n=0)
# 919.5296633400726 	 ai:p:influence(pick_frac=0.2,pick_n=15)
# 909.8378189997823 	 ai:p:tenuki(pick_frac=0.1,pick_n=50)
# 904.8409624060506 	 ai:p:territory(pick_frac=0.2,pick_n=5)
# 899.5574739782032 	 ai:p:rank(kyu_rank=2)
# 893.9674085492053 	 ai:p:tenuki(pick_frac=0.3,pick_n=0)
# 892.3293608633207 	 ai:p:influence(pick_frac=0.05,pick_n=50)
# 885.0027203569002 	 ai:p:influence(pick_frac=0.2,pick_n=10)
# 881.9252847574148 	 ai:p:territory(pick_frac=0.1,pick_n=50)
# 876.0335782491627 	 ai:p:territory(pick_frac=0.2,pick_n=10)
# 869.8251488529871 	 ai:p:rank(kyu_rank=1)
# 861.9261753092183 	 ai:p:tenuki(pick_frac=0.3,pick_n=5)
# 854.8837525066214 	 ai:p:influence(pick_frac=0.2,pick_n=0)
# 852.4338011973616 	 ai:p:influence(pick_frac=0.3,pick_n=10)
# 849.2779807201654 	 ai:p:weighted(weaken_fac=1.5)
# 847.5702393729104 	 ai:p:influence(pick_frac=0.2,pick_n=5)
# 844.6071898713467 	 ai:p:territory(pick_frac=0.05,pick_n=50)
# 839.5494390995922 	 ai:p:influence(pick_frac=0.3,pick_n=0)
# 837.1449293651106 	 ai:p:pick(pick_frac=0.3,pick_n=15)
# 835.0526866507458 	 ai:p:rank(kyu_rank=3)
# 829.1584855060266 	 ai:p:pick(pick_frac=0.1,pick_n=50)
# 828.5840420443486 	 ai:p:tenuki(pick_frac=0.3,pick_n=25)
# 824.5187077157724 	 ai:p:tenuki(pick_frac=0.3,pick_n=10)
# 814.8419513446651 	 ai:p:tenuki(pick_frac=0.0,pick_n=50)
# 813.2392973675484 	 ai:p:rank(kyu_rank=4)
# 812.9900171486104 	 ai:p:tenuki(pick_frac=0.05,pick_n=50)
# 802.4859015305699 	 ai:p:tenuki(pick_frac=0.2,pick_n=10)
# 800.1941964585006 	 ai:p:territory(pick_frac=0.0,pick_n=50)
# 786.5242547137238 	 ai:p:local(pick_frac=0.0,pick_n=10)
# 783.742134393482 	 ai:p:influence(pick_frac=0.1,pick_n=15)
# 783.1285475424697 	 ai:p:territory(pick_frac=0.2,pick_n=15)
# 781.4504821776386 	 ai:p:tenuki(pick_frac=0.2,pick_n=15)
# 773.9552534027605 	 ai:p:tenuki(pick_frac=0.2,pick_n=5)
# 771.5622409965889 	 ai:p:territory(pick_frac=0.1,pick_n=25)
# 764.3748699767076 	 ai:p:local(pick_frac=0.05,pick_n=0)
# 761.3425151814909 	 ai:p:influence(pick_frac=0.1,pick_n=25)
# 753.0368162974905 	 ai:p:influence(pick_frac=0.0,pick_n=50)
# 751.3844060799383 	 ai:p:territory(pick_frac=0.1,pick_n=10)
# 748.0667793799838 	 ai:p:tenuki(pick_frac=0.2,pick_n=0)
# 742.319559533706 	 ai:p:tenuki(pick_frac=0.1,pick_n=25)
# 735.2225150804056 	 ai:p:pick(pick_frac=0.3,pick_n=5)
# 734.3463836992104 	 ai:p:influence(pick_frac=0.1,pick_n=5)
# 733.3835706744866 	 ai:p:influence(pick_frac=0.1,pick_n=10)
# 722.9269433657295 	 ai:p:territory(pick_frac=0.1,pick_n=15)
# 721.7718906468041 	 ai:p:pick(pick_frac=0.3,pick_n=10)
# 721.0696916634708 	 ai:p:rank(kyu_rank=5)
# 720.8201580507932 	 ai:p:territory(pick_frac=0.05,pick_n=25)
# 720.0252762765523 	 ai:p:influence(pick_frac=0.05,pick_n=25)
# 707.0419966832751 	 ai:p:tenuki(pick_frac=0.1,pick_n=10)
# 700.9870352607833 	 ai:p:tenuki(pick_frac=0.05,pick_n=25)
# 699.7770622750076 	 ai:p:pick(pick_frac=0.2,pick_n=25)
# 699.3009134271607 	 ai:p:tenuki(pick_frac=0.05,pick_n=15)
# 696.6361710821669 	 ai:p:influence(pick_frac=0.1,pick_n=0)
# 694.5299562944434 	 ai:p:influence(pick_frac=0.05,pick_n=15)
# 691.728541341106 	 ai:p:tenuki(pick_frac=0.1,pick_n=15)
# 683.2503739146116 	 ai:p:weighted(weaken_fac=1.75)
# 679.053593857607 	 ai:p:territory(pick_frac=0.1,pick_n=0)
# 670.3800274860779 	 ai:p:territory(pick_frac=0.1,pick_n=5)
# 668.9355167208278 	 ai:p:rank(kyu_rank=6)
# 655.8688702121069 	 ai:p:territory(pick_frac=0.05,pick_n=15)
# 653.034846342264 	 ai:p:territory(pick_frac=0.05,pick_n=10)
# 651.7590740351432 	 ai:p:tenuki(pick_frac=0.1,pick_n=5)
# 638.7564515272663 	 ai:p:tenuki(pick_frac=0.05,pick_n=10)
# 633.0598102466381 	 ai:p:pick(pick_frac=0.2,pick_n=15)
# 627.1920495299227 	 ai:p:pick(pick_frac=0.3,pick_n=0)
# 625.7400924613135 	 ai:p:pick(pick_frac=0.05,pick_n=50)
# 623.9923567112676 	 ai:p:rank(kyu_rank=9)
# 596.5805494679103 	 ai:p:influence(pick_frac=0.0,pick_n=25)
# 582.9612324208331 	 ai:p:pick(pick_frac=0.0,pick_n=50)
# 581.3394176799746 	 ai:p:influence(pick_frac=0.05,pick_n=10)
# 558.9244969095101 	 ai:p:territory(pick_frac=0.0,pick_n=25)
# 558.8041751986433 	 ai:p:tenuki(pick_frac=0.05,pick_n=5)
# 555.3883096387729 	 ai:p:rank(kyu_rank=7)
# 548.253132548234 	 ai:p:rank(kyu_rank=8)
# 546.0010475584736 	 ai:p:tenuki(pick_frac=0.0,pick_n=25)
# 541.903988194784 	 ai:p:tenuki(pick_frac=0.1,pick_n=0)
# 539.8003790064159 	 ai:p:weighted(weaken_fac=2.25)
# 533.6789843320622 	 ai:p:territory(pick_frac=0.05,pick_n=5)
# 529.7380142768372 	 ai:p:rank(kyu_rank=10)
# 528.7927812269777 	 ai:p:weighted(weaken_fac=2)
# 524.1385307149782 	 ai:p:pick(pick_frac=0.2,pick_n=10)
# 518.0379975698129 	 ai:p:influence(pick_frac=0.0,pick_n=10)
# 516.0662936853055 	 ai:p:influence(pick_frac=0.05,pick_n=0)
# 508.4043149026838 	 ai:p:territory(pick_frac=0.05,pick_n=0)
# 505.51586687781304 	 ai:p:territory(pick_frac=0.0,pick_n=15)
# 493.69829402625595 	 ai:p:influence(pick_frac=0.05,pick_n=5)
# 467.7366601377787 	 ai:p:tenuki(pick_frac=0.0,pick_n=15)
# 454.34559478536556 	 ai:p:influence(pick_frac=0.0,pick_n=15)
# 449.8831368139436 	 ai:p:pick(pick_frac=0.2,pick_n=5)
# 433.99462426754116 	 ai:p:pick(pick_frac=0.1,pick_n=25)
# 432.9656107403741 	 ai:p:territory(pick_frac=0.0,pick_n=10)
# 425.08860364013395 	 ai:p:rank(kyu_rank=11)
# 404.8533687450005 	 ai:p:rank(kyu_rank=13)
# 366.6321146756113 	 ai:p:tenuki(pick_frac=0.05,pick_n=0)
# 365.9920800271154 	 ai:p:rank(kyu_rank=12)
# 362.32484216786474 	 ai:p:tenuki(pick_frac=0.0,pick_n=10)
# 350.99303625953786 	 ai:p:pick(pick_frac=0.1,pick_n=15)
# 345.4567662404189 	 ai:p:local(pick_frac=0.0,pick_n=5)
# 320.4752162701954 	 ai:p:rank(kyu_rank=15)
# 311.0508695604584 	 ai:p:rank(kyu_rank=14)
# 300.1196670338777 	 ai:p:influence(pick_frac=0.0,pick_n=5)
# 290.18051615640474 	 ai:p:territory(pick_frac=0.0,pick_n=5)
# 278.70817529134575 	 ai:p:rank(kyu_rank=17)
# 276.4387712630035 	 ai:p:pick(pick_frac=0.2,pick_n=0)
# 269.1588034339549 	 ai:p:tenuki(pick_frac=0.0,pick_n=5)
# 258.7102515910701 	 ai:p:pick(pick_frac=0.05,pick_n=25)
# 226.9819711393626 	 ai:p:rank(kyu_rank=16)
# 215.7477264311057 	 ai:p:pick(pick_frac=0.1,pick_n=10)
# 191.87952494649588 	 ai:p:pick(pick_frac=0.05,pick_n=15)
# 171.16162517990938 	 ai:p:rank(kyu_rank=18)
# 154.74305722380404 	 ai:p:pick(pick_frac=0.0,pick_n=25)
# 98.90265423817917 	 ai:p:pick(pick_frac=0.1,pick_n=5)
# 95.61702110357346 	 ai:p:pick(pick_frac=0.05,pick_n=10)
# 8.38540104800357 	 ai:p:pick(pick_frac=0.0,pick_n=15)
# 2.4389400764771505 	 ai:p:pick(pick_frac=0.05,pick_n=5)
# -42.54748977482235 	 ai:p:pick(pick_frac=0.1,pick_n=0)
# -168.45272128001002 	 ai:p:pick(pick_frac=0.0,pick_n=10)
# -271.78277405365293 	 ai:p:pick(pick_frac=0.05,pick_n=0)
# -389.10508353678324 	 ai:p:pick(pick_frac=0.0,pick_n=5)

# %%
calibrate_d = {ai.ai_settings['kyu_rank']:ai for ai in ai_database if ai.strategy==AI_RANK}

# %%
y = sorted(calibrate_d.items(),key=lambda kv:kv[0])
# Out:
# [(-4, <__main__.AI at 0x7fe6a456b5f8>),
#  (-3, <__main__.AI at 0x7fe6cb6525c0>),
#  (-2, <__main__.AI at 0x7fe6a456b668>),
#  (-1, <__main__.AI at 0x7fe6cb652550>),
#  (0, <__main__.AI at 0x7fe6a456b6d8>),
#  (1, <__main__.AI at 0x7fe6a456b748>),
#  (2, <__main__.AI at 0x7fe6cb6524e0>),
#  (3, <__main__.AI at 0x7fe6a456b7b8>),
#  (4, <__main__.AI at 0x7fe6c8384470>),
#  (5, <__main__.AI at 0x7fe6a456b828>),
#  (6, <__main__.AI at 0x7fe6cb652470>),
#  (7, <__main__.AI at 0x7fe6a456b898>),
#  (8, <__main__.AI at 0x7fe6cb652400>),
#  (9, <__main__.AI at 0x7fe6a456b908>),
#  (10, <__main__.AI at 0x7fe6cb652390>),
#  (11, <__main__.AI at 0x7fe6a456b978>),
#  (12, <__main__.AI at 0x7fe6a456b9e8>),
#  (13, <__main__.AI at 0x7fe6a456ba58>),
#  (14, <__main__.AI at 0x7fe6cb652320>),
#  (15, <__main__.AI at 0x7fe6a456bac8>),
#  (16, <__main__.AI at 0x7fe6a456bb38>),
#  (17, <__main__.AI at 0x7fe6a456bba8>),
#  (18, <__main__.AI at 0x7fe6cb652160>)]
